# %% [markdown]
# ### Removes all the duplicate cities from the list. So you can see in how many different cities there is gunviolence.

# %%
import csv
import pandas as pd
# used a shortened dataset, replace 'stage3test.csv' for the big dataset
reader = pd.read_csv('datagun.csv')
city_l = []
# appends city to list and removes duplicates
for city in reader['city_or_county']:
    city = str(city)
    city_l.append(city)
remove = list(set(city_l))
# sorts the cities in alphabetical order 
remove.sort()
print(remove)
print('---------------------------------------------------------------------------------------------------------')
# prints how many different cities are in the list
print (len(remove))
# Out:
# ['Abbeville', 'Abbotsford', 'Abercrombie', 'Aberdeen', 'Abilene', 'Abingdon', 'Abington', 'Abita Springs', 'Absecon', 'Absecon (Galloway)', 'Acadia (county)', 'Acampo', 'Accokeek', 'Accomac', 'Achille', 'Acme', 'Acton', 'Acworth', 'Ada', 'Ada (Byng)', 'Adairsville', 'Adams', 'Adams (county)', 'Adams Run', 'Adamsville', 'Addis', 'Addison', 'Adel', 'Adelanto', 'Adger', 'Adkins', 'Adrian', 'Advance', 'Advance (Bermuda Run)', 'Affton', 'Afton', 'Agate', 'Agoura Hills', 'Agra', 'Agua Dulce', 'Agua Fria', 'Aguanga', 'Ahoskie', 'Ahsahka', 'Aiea', 'Aiken', 'Aiken (county)', 'Aiken County', 'Airway Heights', 'Ajo', 'Akron', 'Akron (East Akron)', 'Akron (Newstead)', 'Ala Moana', 'Alabaster', 'Alachua', 'Alachua (county)', 'Alamance', 'Alamance (county)', 'Alameda', 'Alameda County', 'Alamo', 'Alamogordo', 'Alamosa', 'Alapaha', 'Albany', 'Albany ', 'Albany (Colonie)', 'Albany (Loudonville)', 'Albemarle', 'Albemarle (county)', 'Alberta', 'Albertville', 'Albion', 'Albright', 'Albuquerque', 'Albuquerque (Los Ranchos De Albuquerque)', 'Albuquerque (Los Ranchos)', 'Albuquerque (Manzano)', 'Alcoa', 'Alcona (county)', 'Alcorn (county)', 'Alcova', 'Alden', 'Alderpoint', 'Alderson', 'Aldie', 'Aledo', 'Alex', 'Alexander', 'Alexander City', 'Alexander City ', 'Alexandria', 'Alexandria (Fort Hunt)', 'Alexandria (Franconia)', 'Alexandria (Tanglewood)', 'Alexandria Bay', 'Alexandria Bay (Alexandria)', 'Alexis', 'Alford', 'Alfred', 'Alfred (Lyman)', 'Algiers', 'Algodones', 'Algonquin', 'Alhambra', 'Alice', 'Aliceville', 'Aliquippa', 'Aliso Viejo', 'Allapattah', 'Allegan', 'Allegany', 'Alleghany (county)', 'Allen', 'Allen (county)', 'Allen Park', 'Allendale', 'Allenhurst', 'Allenton', 'Allentown', 'Alliance', 'Allison', 'Allyn', 'Alma', 'Almon', 'Almond', 'Almont', 'Almyra', 'Alna', 'Aloha', 'Alorton', 'Alpaugh', 'Alpena', 'Alpharetta', 'Alpharetta (Johns Creek)', 'Alpharetta (Milton)', 'Alpine', 'Alsea', 'Alsip', 'Alstead', 'Alta', 'Altadena', 'Altamont', 'Altamonte Springs', 'Altavista', 'Altha', 'Altheimer', 'Alto', 'Alton', 'Altona', 'Altoona', 'Alturas', 'Altus', 'Alum Creek', 'Alva', 'Alvin', 'Ama', 'Amado', 'Amarillo', 'Amazonia', 'Amboy', 'Amelia', 'Amelia Court House', 'American Canyon', 'American Fork', 'American Fork (Highland)', 'Americus', 'Ames', 'Amherst', 'Amherst (South Amherst)', 'Amite', 'Amite (Grangeville)', 'Amity', 'Amityville', 'Amityville (North Amityville)', 'Ammon', 'Amory', 'Amory ', 'Amsterdam', 'Amsterdam (Perth)', 'Anacoco', 'Anaconda', 'Anadarko', 'Anaheim', 'Anaheim (Anaheim Hills)', 'Anahuac', 'Anamosa', 'Anchorage', 'Ancram', 'Andalusia', 'Anderson', 'Anderson (Chesterfield)', 'Anderson (county)', 'Anderson County', 'Andersonville', 'Andover', 'Andover (Byram Township)', 'Andrews', 'Aneth', 'Angelica', 'Angelina (county)', 'Angels Camp', 'Angelus Oaks', 'Angie', 'Angier', 'Angleton', 'Angola', 'Angwin', 'Aniwa', 'Ankeny', 'Anmoore', 'Ann Arbor', 'Anna', 'Anna Maria', 'Annada', 'Annandale', 'Annapolis', 'Annapolis Junction', 'Anne Arundel', 'Anne Arundel (county)', 'Anniston', 'Anson', 'Anson (Starks)', 'Ansonia', 'Ansted', 'Antelope', 'Anthon', 'Anthony', 'Antigo', 'Antioch', 'Antlers', 'Antreville (county)', 'Antwerp', 'Anza', 'Apache', 'Apache Junction', 'Apalachicola', 'Apex', 'Apison', 'Apollo Beach', 'Apopka', 'Apopka ', 'Appalachia', 'Appalachia (Exeter)', 'Appanoose (county)', 'Apple Grove', 'Apple Valley', 'Appleton', 'Appleton (Grand Chute)', 'Appling', 'Appomattox', 'Arab', 'Arabi', 'Aragon', 'Aransas (county)', 'Aransas Pass', 'Arapahoe', 'Ararat', 'Arboles', 'Arbuckle', 'Arcade', 'Arcadia', 'Arcanum', 'Arcata', 'Arcata (Manila)', 'Archdale', 'Archer', 'Arcola', 'Arden', 'Arden (West Haven)', 'Ardmore', 'Ardmore (Dickson)', 'Argentine Township', 'Argos', 'Argusville', 'Argyle', 'Ariton', 'Arivaca', 'Arizona City', 'Arkadelphia', 'Arkansas City', 'Arkdale (Big Flats)', 'Arlee', 'Arleta', 'Arlington', 'Arlington (Lakeland)', 'Arlington Heights', 'Arma', 'Armona', 'Armstrong', 'Armuchee', 'Arnaudville', 'Arnega ...
# ---------------------------------------------------------------------------------------------------------
# 11163

# %% [markdown]
# ### Puts all the cities in a list and searches for the most common cities in the list. This way you can look at which  cities have the most gunviolence.

# %%
import csv
import pandas as pd
from collections import Counter
# used a shortened dataset, replace 'stage3test.csv' for the big dataset
reader = pd.read_csv('datagun.csv')
common_l = []
# appends all the cities in dataset to list
for city in reader['city_or_county']:
    city = str(city)
    common_l.append(city)
print(common_l)
print('---------------------------------------------------------------------------------------------------------')

cnt = Counter(common_l)
# change the value for how many cities you want in your result
print(cnt.most_common(10))
# Out:
# ['Muskegon', 'Newark', 'Queens', 'Brooklyn', 'Springfield', 'Columbus', 'Syracuse', 'Bibb County', 'Prince William County', 'Hampton', 'North Charleston', 'Baltimore', 'Wilmington', 'Grand Junction', 'North Charleston', 'Springfield', 'Huntsville', 'Camden', 'New Orleans', 'Hurricane', 'Fort Wayne', 'Marrero', 'Pinckneyville', 'Bronx', 'Canon City', 'Bronx', 'Lubbock', 'Johns Island', 'Houston', 'Newport News', 'Milton', 'Fort Myers', 'Marrero', 'Tuscaloosa', 'Bogue Chitto', 'Clementon', 'Olanta', 'Janesville', 'Crenshaw', 'Tolleson', 'Lihue', 'Georgetown', 'Homestead', 'Orlando', 'Orlando', 'Cynthiana', 'Orlando', 'Toledo', 'Wichita', 'Fort Wayne', 'New Orleans', 'Princeton', 'Warner Robins', 'Borger', 'Milwaukee', 'Deltona', 'Providence', 'Duplin County', 'Rio Rico', 'Tampa', 'Toledo', 'Raleigh', 'Buffalo', 'Baltimore', 'Norfolk', 'Port Arthur', 'Merced', 'New Carrollton', 'Fresno', 'Glendale', 'Lubbock', 'Tulalip', 'Lawton', 'Quincy', 'Greensboro', 'Gloucester Township', 'Mount Laurel', 'Belleville', 'Seattle', 'Dover', 'Seattle', 'Columbus', 'Franklin', 'Poughkeepsie', 'Springfield', 'Tupelo', 'Falls Church', 'Bucksport', 'North Charleston', 'New Haven', 'Chicago', 'Winston-Salem', 'Brooklyn', 'Okmulgee County', 'Gadsden', 'Columbus', 'Fort Dodge', 'Toms River', 'Fort Wayne', 'Little Rock', 'New Orleans', 'Greenville', 'Douglas', 'Huntsville', 'New Orleans', 'Huntsville', 'Denver', 'Cromwell', 'Newton', 'Birmingham', 'Columbus', 'Baltimore', 'Detroit', 'Los Angeles', 'Atlanta', 'Saint Marys', 'Detroit', 'Shreveport', 'Staten Island', 'Brooklyn', 'Bridgeton', 'Chicago', 'Colorado Springs', 'Hebbronville', 'Milwaukee', 'Humboldt', 'Chesapeake', 'Cleveland', 'Phoenix', 'Riviera Beach', 'San Antonio', 'Russell County', 'Corpus Christi', 'Jersey City', 'Harker Heights', 'Niagara Falls', 'Chesapeake', 'Fort Worth', 'Newport News', 'West Allis', 'Baltimore', 'Newport News', 'Las Vegas', 'Milwaukee', 'Baltimore', 'Newport News', 'Corpus Christi', 'Walker', 'Bridgeton', 'Chelsea', 'Richmond', 'Fort Wayne', 'Bakersfield', 'Springfield', 'Pine Bluff', 'Saint Louis', 'Cape Horn', 'Detroit', 'Atlanta', 'Chicago', 'Detroit', 'Sunrise', 'Saint Louis', 'Pinellas Park', 'Richmond', 'Trenton', 'Iowa City', 'Huntsville', 'Killeen', 'Davidson County', 'Rockford', 'Erwin', 'Niagara Falls', 'Syracuse', 'Detroit (Redford Charter Township)', 'Richland Parish (county)', 'Bronx', 'Indianapolis', 'Brooklyn', 'Castlewood', 'Dayton', 'Charleston', 'Rochester', 'Orlando', 'Columbus County', 'Jacksonville', 'Miami Township', 'Baton Rouge', 'Baltimore', "Prince George's County", 'Fort Lee', 'Saint Petersburg', 'Killeen', 'Huntington', 'San Jose', 'Baltimore', 'Nampa', 'Davison', 'Oxford', 'Laurel', 'Indianapolis', 'Brownsville', 'Elyria', 'Montgomery', 'Tampa', 'Columbia', 'Merritt Island', 'Crestview', 'Davie', 'Austin', 'Killeen', 'Rock Hill', 'Union Grove', 'Indianapolis', 'Durham', 'Mullins', 'Surprise', 'Durham', 'Phoenix', 'Indianapolis', 'Durham', 'Detroit', 'Portland', 'Colorado Springs', 'Thornton', 'Columbia', 'National City', 'South Bend', 'Hackensack', 'Auburn', 'Conroe', 'Keansburg', 'Marietta', 'Shenandoah', 'Cheyenne', 'New Orleans', 'Dover', 'Salt Lake City', 'Knoxville', 'Orlando', 'Little Rock', 'New Orleans', 'Rock Hill', 'Amarillo', 'Nashville', 'Vista', 'Chico', 'Galveston', 'El Paso', 'Burien', 'Brooklyn', 'Austin', 'Saint Petersburg', 'Orlando', 'Portland', 'Greenacres', 'Lee', 'Portland', 'Crestview', 'Jacksonville', 'Tucson', 'Columbus', 'San Diego', 'Vicksburg', 'Kansas City', 'Burlington Township', 'Fort Collins', 'Richmond', 'New Orleans', 'Chattanooga', 'Saginaw', 'Cincinnati (Evanston)', 'Richland', 'Tahlequah', 'Dallas', 'Dallas', 'Newport News', 'Lehigh Acres', 'Hondo', 'Huntsville', 'Des Moines', 'New Haven', 'Detroit', 'Camden', 'Boone County', 'Green Valley', 'Natchez', 'Baton Rouge', 'Columbus', 'Huntsville', 'Durham', 'Houston', 'Harris County', 'Queens', 'New Orleans', 'Huntsville', 'Cleveland', 'Baton Rouge', 'Odent ...
# ---------------------------------------------------------------------------------------------------------
# [('Chicago', 10278), ('Baltimore', 3337), ('New Orleans', 2892), ('Saint Louis', 2427), ('Milwaukee', 2407), ('Jacksonville', 2369), ('Memphis', 2300), ('Columbus', 2134), ('Houston', 2000), ('Indianapolis', 1798)]
