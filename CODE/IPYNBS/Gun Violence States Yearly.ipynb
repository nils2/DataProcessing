# %%
import pandas as pd
import csv
df = pd.read_csv("../DATA/datagun.csv")
df
# Out:
#         incident_id  day  month  year           state  \
# 0             95289    1      1  2014        Michigan
# 1             92401    1      1  2014      New Jersey
# 2             92383    1      1  2014        New York
# 3             92142    1      1  2014        New York
# 4             95261    1      1  2014        Missouri
# 5             92272    1      1  2014         Georgia
# 6             92428    1      1  2014        New York
# 7             94205    1      1  2014        Kentucky
# 8             92218    1      1  2014         Georgia
# 9            104905    1      1  2014        Virginia
# 10            92423    1      1  2014    Pennsylvania
# 11            94154    1      1  2014        Virginia
# 12            92215    1      1  2014  South Carolina
# 13           104022    1      1  2014        Maryland
# 14            92357    1      1  2014        Delaware
# 15            92790    1      1  2014        Colorado
# ...

# %%
states = ['Utah', 'New Jersey', 'Nebraska', 'Montana', 'Oklahoma', 'Colorado', 
          'Tennessee', 'Alaska', 'Georgia', 'South Carolina', 'Indiana', 'Maryland', 
          'Mississippi', 'Virginia', 'South Dakota', 'Wisconsin', 'Michigan', 'Florida',
          'Arizona', 'Louisiana', 'Rhode Island', 'Arkansas', 'Texas', 'Idaho', 'Maine',
          'Massachusetts', 'Kentucky', 'North Carolina', 'California', 'Hawaii', 'Oregon',
          'West Virginia', 'New Hampshire', 'Minnesota', 'Missouri', 'New York', 'New Mexico',
          'Pennsylvania', 'Nevada', 'North Dakota', 'Washington', 'Iowa', 'Alabama', 'Wyoming',
          'Kansas', 'Connecticut', 'Illinois', 'District of Columbia', 'Ohio', 'Delaware']
new_states =[]
state_incidents = {}
state_counter = 0
for j in range(len(df)):
    for i in df.loc[j]:
        if i in states:
            new_states.append(i)
for x in set(df.state):
    for y in new_states:
        if y == x:
            state_counter += 1
    state_incidents[x]= state_counter
    state_counter = 0
for i in sorted(state_incidents):
    print(i)
    print(state_incidents[i])
# Out:
# Alabama
# 5369
# Alaska
# 1291
# Arizona
# 2263
# Arkansas
# 2753
# California
# 15945
# Colorado
# 3066
# Connecticut
# 2981
# Delaware
# 1646
# District of Columbia
# 3084
# Florida
# 14598
# Georgia
# 8710
# Hawaii
# 277
# Idaho
# 633
# Illinois
# 16791
# Indiana
# 5567
# Iowa
# 2438
# Kansas
# 2069
# Kentucky
# 4001
# Louisiana
# 7717
# Maine
# 891
# Maryland
# 5635
# Massachusetts
# 5787
# Michigan
# 5746
# Minnesota
# 2274
# Mississippi
# 3493
# Missouri
# 6432
# Montana
# 621
# Nebraska
# 1595
# Nevada
# 1883
# New Hampshire
# 934
# New Jersey
# 5212
# New Mexico
# 1592
# New York
# 9486
# North Carolina
# 8444
# North Dakota
# 552
# Ohio
# 9806
# Oklahoma
# 3312
# Oregon
# 2231
# Pennsylvania
# 8549
# Rhode Island
# 873
# South Carolina
# 6738
# South Dakota
# 520
# Tennessee
# 7348
# Texas
# 12967
# Utah
# 1023
# Vermont
# 0
# Virginia
# 5656
# Washington
# 6471
# West Virginia
# 1496
# Wisconsin
# 4657
# Wyoming
# 533

# %%
states = ['Utah', 'New Jersey', 'Nebraska', 'Montana', 'Oklahoma', 'Colorado', 
          'Tennessee', 'Alaska', 'Georgia', 'South Carolina', 'Indiana', 'Maryland', 
          'Mississippi', 'Virginia', 'South Dakota', 'Wisconsin', 'Michigan', 'Florida',
          'Arizona', 'Louisiana', 'Rhode Island', 'Arkansas', 'Texas', 'Idaho', 'Maine',
          'Massachusetts', 'Kentucky', 'North Carolina', 'California', 'Hawaii', 'Oregon',
          'West Virginia', 'New Hampshire', 'Minnesota', 'Missouri', 'New York', 'New Mexico',
          'Pennsylvania', 'Nevada', 'North Dakota', 'Washington', 'Iowa', 'Alabama', 'Wyoming',
          'Kansas', 'Connecticut', 'Illinois', 'District of Columbia', 'Ohio', 'Delaware']
new_states =[]
state_incidents = {}
state_counter = 0
for j in range(len(df[df.year == 2014])):
    for i in df.loc[j]:
        if i in states:
            new_states.append(i)
for x in set(df.state):
    for y in new_states:
        if y == x:
            state_counter += 1
    state_incidents[x]= state_counter
    state_counter = 0
for i in sorted(state_incidents):
    print(i)
    print(state_incidents[i])
# Out:
# Alabama
# 1315
# Alaska
# 146
# Arizona
# 555
# Arkansas
# 570
# California
# 3709
# Colorado
# 554
# Connecticut
# 578
# Delaware
# 495
# District of Columbia
# 835
# Florida
# 3128
# Georgia
# 2029
# Hawaii
# 47
# Idaho
# 115
# Illinois
# 3059
# Indiana
# 1191
# Iowa
# 562
# Kansas
# 381
# Kentucky
# 974
# Louisiana
# 1894
# Maine
# 183
# Maryland
# 1255
# Massachusetts
# 964
# Michigan
# 1437
# Minnesota
# 450
# Mississippi
# 784
# Missouri
# 1272
# Montana
# 128
# Nebraska
# 346
# Nevada
# 376
# New Hampshire
# 229
# New Jersey
# 1513
# New Mexico
# 318
# New York
# 1903
# North Carolina
# 2155
# North Dakota
# 110
# Ohio
# 2355
# Oklahoma
# 642
# Oregon
# 401
# Pennsylvania
# 2258
# Rhode Island
# 188
# South Carolina
# 1653
# South Dakota
# 71
# Tennessee
# 1583
# Texas
# 3104
# Utah
# 215
# Vermont
# 0
# Virginia
# 1268
# Washington
# 1500
# West Virginia
# 361
# Wisconsin
# 1058
# Wyoming
# 72

# %%
states = ['Utah', 'New Jersey', 'Nebraska', 'Montana', 'Oklahoma', 'Colorado', 
          'Tennessee', 'Alaska', 'Georgia', 'South Carolina', 'Indiana', 'Maryland', 
          'Mississippi', 'Virginia', 'South Dakota', 'Wisconsin', 'Michigan', 'Florida',
          'Arizona', 'Louisiana', 'Rhode Island', 'Arkansas', 'Texas', 'Idaho', 'Maine',
          'Massachusetts', 'Kentucky', 'North Carolina', 'California', 'Hawaii', 'Oregon',
          'West Virginia', 'New Hampshire', 'Minnesota', 'Missouri', 'New York', 'New Mexico',
          'Pennsylvania', 'Nevada', 'North Dakota', 'Washington', 'Iowa', 'Alabama', 'Wyoming',
          'Kansas', 'Connecticut', 'Illinois', 'District of Columbia', 'Ohio', 'Delaware']
new_states =[]
state_incidents = {}
state_counter = 0
for j in range(len(df[df.year == 2014]), len(df[df.year == 2014])+len(df[df.year == 2015])):
    for i in df.loc[j]:
        if i in states:
            new_states.append(i)
for x in set(df.state):
    for y in new_states:
        if y == x:
            state_counter += 1
    state_incidents[x]= state_counter
    state_counter = 0
for i in sorted(state_incidents):
    print(i)
    print(state_incidents[i])
# Out:
# Alabama
# 1032
# Alaska
# 377
# Arizona
# 478
# Arkansas
# 537
# California
# 3218
# Colorado
# 782
# Connecticut
# 732
# Delaware
# 366
# District of Columbia
# 537
# Florida
# 2691
# Georgia
# 2766
# Hawaii
# 75
# Idaho
# 172
# Illinois
# 3412
# Indiana
# 1303
# Iowa
# 582
# Kansas
# 457
# Kentucky
# 913
# Louisiana
# 1665
# Maine
# 231
# Maryland
# 1280
# Massachusetts
# 1329
# Michigan
# 1243
# Minnesota
# 406
# Mississippi
# 661
# Missouri
# 1696
# Montana
# 137
# Nebraska
# 371
# Nevada
# 487
# New Hampshire
# 208
# New Jersey
# 1059
# New Mexico
# 392
# New York
# 2893
# North Carolina
# 1848
# North Dakota
# 148
# Ohio
# 2085
# Oklahoma
# 832
# Oregon
# 684
# Pennsylvania
# 1757
# Rhode Island
# 225
# South Carolina
# 1688
# South Dakota
# 101
# Tennessee
# 1749
# Texas
# 3209
# Utah
# 317
# Vermont
# 0
# Virginia
# 1315
# Washington
# 1463
# West Virginia
# 336
# Wisconsin
# 1113
# Wyoming
# 201

# %%
states = ['Utah', 'New Jersey', 'Nebraska', 'Montana', 'Oklahoma', 'Colorado', 
          'Tennessee', 'Alaska', 'Georgia', 'South Carolina', 'Indiana', 'Maryland', 
          'Mississippi', 'Virginia', 'South Dakota', 'Wisconsin', 'Michigan', 'Florida',
          'Arizona', 'Louisiana', 'Rhode Island', 'Arkansas', 'Texas', 'Idaho', 'Maine',
          'Massachusetts', 'Kentucky', 'North Carolina', 'California', 'Hawaii', 'Oregon',
          'West Virginia', 'New Hampshire', 'Minnesota', 'Missouri', 'New York', 'New Mexico',
          'Pennsylvania', 'Nevada', 'North Dakota', 'Washington', 'Iowa', 'Alabama', 'Wyoming',
          'Kansas', 'Connecticut', 'Illinois', 'District of Columbia', 'Ohio', 'Delaware']
new_states =[]
state_incidents = {}
state_counter = 0
for j in range(len(df[df.year == 2014])+len(df[df.year == 2015]), len(df[df.year == 2014])+len(df[df.year == 2015])+len(df[df.year == 2016])):
    for i in df.loc[j]:
        if i in states:
            new_states.append(i)
for x in set(df.state):
    for y in new_states:
        if y == x:
            state_counter += 1
    state_incidents[x]= state_counter
    state_counter = 0
for i in sorted(state_incidents):
    print(i)
    print(state_incidents[i])
# Out:
# Alabama
# 1246
# Alaska
# 417
# Arizona
# 523
# Arkansas
# 664
# California
# 3522
# Colorado
# 741
# Connecticut
# 771
# Delaware
# 317
# District of Columbia
# 463
# Florida
# 3983
# Georgia
# 1584
# Hawaii
# 76
# Idaho
# 140
# Illinois
# 4712
# Indiana
# 1355
# Iowa
# 621
# Kansas
# 529
# Kentucky
# 897
# Louisiana
# 1856
# Maine
# 231
# Maryland
# 1235
# Massachusetts
# 1438
# Michigan
# 1178
# Minnesota
# 414
# Mississippi
# 811
# Missouri
# 1460
# Montana
# 154
# Nebraska
# 361
# Nevada
# 488
# New Hampshire
# 252
# New Jersey
# 1150
# New Mexico
# 371
# New York
# 2419
# North Carolina
# 1930
# North Dakota
# 137
# Ohio
# 2220
# Oklahoma
# 824
# Oregon
# 519
# Pennsylvania
# 2000
# Rhode Island
# 222
# South Carolina
# 1400
# South Dakota
# 130
# Tennessee
# 1815
# Texas
# 3237
# Utah
# 222
# Vermont
# 0
# Virginia
# 1354
# Washington
# 1187
# West Virginia
# 348
# Wisconsin
# 803
# Wyoming
# 138

# %%
states = ['Utah', 'New Jersey', 'Nebraska', 'Montana', 'Oklahoma', 'Colorado', 
          'Tennessee', 'Alaska', 'Georgia', 'South Carolina', 'Indiana', 'Maryland', 
          'Mississippi', 'Virginia', 'South Dakota', 'Wisconsin', 'Michigan', 'Florida',
          'Arizona', 'Louisiana', 'Rhode Island', 'Arkansas', 'Texas', 'Idaho', 'Maine',
          'Massachusetts', 'Kentucky', 'North Carolina', 'California', 'Hawaii', 'Oregon',
          'West Virginia', 'New Hampshire', 'Minnesota', 'Missouri', 'New York', 'New Mexico',
          'Pennsylvania', 'Nevada', 'North Dakota', 'Washington', 'Iowa', 'Alabama', 'Wyoming',
          'Kansas', 'Connecticut', 'Illinois', 'District of Columbia', 'Ohio', 'Delaware']
new_states =[]
state_incidents = {}
state_counter = 0
for j in range(len(df[df.year == 2014])+len(df[df.year == 2015])+len(df[df.year == 2016]), len(df[df.year == 2014])+len(df[df.year == 2015])+len(df[df.year == 2016])+len(df[df.year == 2017])):
    for i in df.loc[j]:
        if i in states:
            new_states.append(i)
for x in set(df.state):
    for y in new_states:
        if y == x:
            state_counter += 1
    state_incidents[x]= state_counter
    state_counter = 0
for i in sorted(state_incidents):
    print(i)
    print(state_incidents[i])
# Out:
# Alabama
# 1460
# Alaska
# 303
# Arizona
# 572
# Arkansas
# 801
# California
# 4503
# Colorado
# 786
# Connecticut
# 752
# Delaware
# 374
# District of Columbia
# 1121
# Florida
# 4053
# Georgia
# 1952
# Hawaii
# 65
# Idaho
# 156
# Illinois
# 4890
# Indiana
# 1429
# Iowa
# 567
# Kansas
# 559
# Kentucky
# 1012
# Louisiana
# 1928
# Maine
# 201
# Maryland
# 1545
# Massachusetts
# 1719
# Michigan
# 1329
# Minnesota
# 741
# Mississippi
# 1000
# Missouri
# 1697
# Montana
# 163
# Nebraska
# 428
# Nevada
# 429
# New Hampshire
# 199
# New Jersey
# 1302
# New Mexico
# 435
# New York
# 1979
# North Carolina
# 2081
# North Dakota
# 132
# Ohio
# 2628
# Oklahoma
# 831
# Oregon
# 500
# Pennsylvania
# 2098
# Rhode Island
# 189
# South Carolina
# 1679
# South Dakota
# 194
# Tennessee
# 1844
# Texas
# 2797
# Utah
# 218
# Vermont
# 0
# Virginia
# 1446
# Washington
# 2004
# West Virginia
# 379
# Wisconsin
# 1339
# Wyoming
# 105

# %%
states = ['Utah', 'New Jersey', 'Nebraska', 'Montana', 'Oklahoma', 'Colorado', 
          'Tennessee', 'Alaska', 'Georgia', 'South Carolina', 'Indiana', 'Maryland', 
          'Mississippi', 'Virginia', 'South Dakota', 'Wisconsin', 'Michigan', 'Florida',
          'Arizona', 'Louisiana', 'Rhode Island', 'Arkansas', 'Texas', 'Idaho', 'Maine',
          'Massachusetts', 'Kentucky', 'North Carolina', 'California', 'Hawaii', 'Oregon',
          'West Virginia', 'New Hampshire', 'Minnesota', 'Missouri', 'New York', 'New Mexico',
          'Pennsylvania', 'Nevada', 'North Dakota', 'Washington', 'Iowa', 'Alabama', 'Wyoming',
          'Kansas', 'Connecticut', 'Illinois', 'District of Columbia', 'Ohio', 'Delaware']
new_states =[]
state_incidents = {}
state_counter = 0
for j in range(len(df[df.year == 2014])+len(df[df.year == 2015])+len(df[df.year == 2016])+len(df[df.year == 2017]), len(df[df.year == 2014])+len(df[df.year == 2015])+len(df[df.year == 2016])+len(df[df.year == 2017])+ len(df[df.year == 2018])):
    for i in df.loc[j]:
        if i in states:
            new_states.append(i)
for x in set(df.state):
    for y in new_states:
        if y == x:
            state_counter += 1
    state_incidents[x]= state_counter
    state_counter = 0
for i in sorted(state_incidents):
    print(i)
    print(state_incidents[i])
# Out:
# Alabama
# 316
# Alaska
# 48
# Arizona
# 135
# Arkansas
# 181
# California
# 993
# Colorado
# 203
# Connecticut
# 148
# Delaware
# 94
# District of Columbia
# 128
# Florida
# 743
# Georgia
# 379
# Hawaii
# 14
# Idaho
# 50
# Illinois
# 718
# Indiana
# 289
# Iowa
# 106
# Kansas
# 143
# Kentucky
# 205
# Louisiana
# 374
# Maine
# 45
# Maryland
# 320
# Massachusetts
# 337
# Michigan
# 559
# Minnesota
# 263
# Mississippi
# 237
# Missouri
# 307
# Montana
# 39
# Nebraska
# 89
# Nevada
# 103
# New Hampshire
# 46
# New Jersey
# 188
# New Mexico
# 76
# New York
# 292
# North Carolina
# 430
# North Dakota
# 25
# Ohio
# 518
# Oklahoma
# 183
# Oregon
# 127
# Pennsylvania
# 436
# Rhode Island
# 49
# South Carolina
# 318
# South Dakota
# 24
# Tennessee
# 357
# Texas
# 620
# Utah
# 51
# Vermont
# 0
# Virginia
# 273
# Washington
# 317
# West Virginia
# 72
# Wisconsin
# 344
# Wyoming
# 17
